# %% [markdown]
# #### 오존 측정치(ozone.csv) : feature - 태양세기, 바람세기, 온도("Solar.R","Wind","Temp") / label - 오존치("Ozone")

# %% [markdown]
# ###여러 독립변수와 종속변수 사용

# %%
import tensorflow as tf
tf.__version__
# Out:
# '2.9.2'

# %% [markdown]
# ###Raw Data Loading

# %%
import pandas as pd

# %%
df = pd.read_csv('./ozone.csv')
# df
# df.describe()
# df.info()
df.keys()
# Out:
# Index(['Ozone', 'Solar.R', 'Wind', 'Temp', 'Month', 'Day'], dtype='object')

# %%
train_df = df[["Solar.R","Wind","Temp",'Ozone']]
train_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 153 entries, 0 to 152
# Data columns (total 4 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   Solar.R  146 non-null    float64
#  1   Wind     153 non-null    float64
#  2   Temp     153 non-null    int64
#  3   Ozone    116 non-null    float64
# dtypes: float64(3), int64(1)
# memory usage: 4.9 KB

# %% [markdown]
# ###Data PreProcessing

# %% [markdown]
# ####Missing Value(결측치)

# %%
#Remove Row
train_preprocessing = train_df.dropna(how='any')
train_preprocessing.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 111 entries, 0 to 152
# Data columns (total 4 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   Solar.R  111 non-null    float64
#  1   Wind     111 non-null    float64
#  2   Temp     111 non-null    int64
#  3   Ozone    111 non-null    float64
# dtypes: float64(3), int64(1)
# memory usage: 4.3 KB

# %% [markdown]
# ####이상치 처리 : 생략

# %% [markdown]
# ####정규화(Normalization)

# %% [markdown]
# #####각 columns 분리

# %%
feature_normalization = train_preprocessing[["Solar.R","Wind","Temp"]] # Dont Need 2차원 Numpy 변환
feature_normalization.shape
# Out:
# (111, 3)

# %%
target_normalization = train_preprocessing['Ozone'].values.reshape(-1,1) # 2차원 Numpy 변환
target_normalization.shape
# Out:
# (111, 1)

# %% [markdown]
# #####Min-Max Scaling

# %%
from sklearn.preprocessing import MinMaxScaler

# %%
feature_minmaxscaler = MinMaxScaler()
feature_minmaxscaler.fit(feature_normalization)
feature_minmaxscaler.scale_, feature_minmaxscaler.min_
# Out:
# (array([0.0030581 , 0.05434783, 0.025     ]),
#  array([-0.02140673, -0.125     , -1.425     ]))

# %%
feature_set = feature_minmaxscaler.transform(feature_normalization)
# feature_set

# %%
target_minmaxscaler = MinMaxScaler()
target_minmaxscaler.fit(target_normalization)
target_minmaxscaler.min_
# Out:
# array([-0.00598802])

# %%
target_set = target_minmaxscaler.transform(target_normalization)
# target_set

# %% [markdown]
# ###Model 구현

# %%
import tensorflow as tf

# %% [markdown]
# #### input layer

# %%
input = tf.keras.layers.Input(shape=(3,))

# %% [markdown]
# ####hidden layers

# %%
hiddens = tf.keras.layers.Flatten()(input)

# %% [markdown]
# #### output layer

# %%
output = tf.keras.layers.Dense(units=1, activation='linear')(hiddens)

# %% [markdown]
# #### Model

# %%
model = tf.keras.Model(inputs=input, outputs=output)

# %% [markdown]
# ###Model 설정

# %% [markdown]
# ####Optimizer 선택

# %%
optimizer = tf.keras.optimizers.SGD(learning_rate=1e-2)

# %% [markdown]
# ####Loss function 선택

# %%
loss = tf.keras.losses.MeanSquaredError()
#loss = tf.keras.losses.MeanAbsoluteError()

# %%
model.compile(optimizer=optimizer, loss=loss)

# %% [markdown]
# ###Model 학습

# %%
# rename
feature = feature_set.copy()
target = target_set.copy()

# %%
epoch = 500
history = model.fit(x=feature, y=target, epochs=epoch, shuffle=True, verbose=0)

# %% [markdown]
# ###Model예측

# %% [markdown]
# ####예측할 데이터 생성

# %%
#온도 화씨 70도 일 경우
import numpy as np

unkown_data = np.array([[180,8,75]])

# %% [markdown]
# ####PreProcessing 적용

# %%
unkown_data_minmaxscaler = feature_minmaxscaler.transform(unkown_data)
# Out:
# /usr/local/lib/python3.7/dist-packages/sklearn/base.py:451: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   "X does not have valid feature names, but"

# %%
predict_result = model.predict(unkown_data_minmaxscaler)
predict_result
# Out:
# 1/1 [==============================] - 0s 17ms/step
# array([[0.24853382]], dtype=float32)

# %% [markdown]
# ####PreProcessing 역적용

# %%
target_minmaxscaler.inverse_transform(predict_result)
# Out:
# array([[42.50515]], dtype=float32)
